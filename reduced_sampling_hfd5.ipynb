# %%
# In case of file already open error
file2.close()
f.close()

# %%
import h5py
filename = "2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5"

f = h5py.File(filename,'r')

filename2 = "2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f_reduced.hdf5"
file2 = h5py.File(filename2,'w')

emg2qwerty_group = f["emg2qwerty"]
print(emg2qwerty_group)
print(list(emg2qwerty_group.keys())[0])
emg2qwerty_timeseries = emg2qwerty_group["timeseries"]

timeseries_temp = emg2qwerty_timeseries[()]
print(timeseries_temp.shape)
timeseries_temp = timeseries_temp[::2]
print(timeseries_temp.shape)
print(list(emg2qwerty_timeseries.attrs.keys()))

group = f["emg2qwerty"]
group.copy(group,file2)
grp = file2["emg2qwerty"]
del grp["timeseries"]
grp.create_dataset("timeseries",data=timeseries_temp)

file2.close()
f.close()
# Out:
# <HDF5 group "/emg2qwerty" (1 members)>
# timeseries
# (1790654,)
# (895327,)
# []

# %%
import h5py
filename = "2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f_reduced.hdf5"

f = h5py.File(filename,'r')
#print(list(f.keys()))
emg2qwerty_group = f["emg2qwerty"]
print(emg2qwerty_group)
print(list(emg2qwerty_group.keys())[0])
emg2qwerty_timeseries = emg2qwerty_group["timeseries"]
print(emg2qwerty_timeseries[()][0])
print(list(emg2qwerty_group.attrs.items()))
f.close()
# Out:
# <HDF5 group "/emg2qwerty" (1 members)>
# timeseries
# ([ -7.8442564 ,  -8.297102  ,  -5.5581975 ,  -3.2034729 ,  -5.5583405 ,  -2.8798249 ,  -5.4398365 ,  -3.751408  ,  -3.0964963 ,  -2.6807709 ,  -0.02554606,   0.26252913,  -0.3808922 ,  -5.6477375 , -10.08092   ,  -7.1542344 ], 1.62267997e+09, [16.623707 , 16.623707 , 26.59793  , 17.731955 , 23.27319  ,  6.6494827, 23.27319  , 19.948448 , 13.298965 , 15.515461 , 16.623707 , 19.948448 , 12.190719 , 17.731955 , 21.056696 , 16.623707 ])
# ...
